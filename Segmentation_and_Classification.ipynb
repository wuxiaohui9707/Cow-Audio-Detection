# %%
from utils import Supervised_Segmentation as SS
import os

training_dirs = [os.path.join('E:/Files','Acoustic_Data', 'Ruminating'), 
               os.path.join('E:/Files','Acoustic_Data', 'Gulp'),
               os.path.join('E:/Files','Acoustic_Data', 'Breath'),
               os.path.join('E:/Files','Acoustic_Data', 'Burp')
] 
model_name = "svm_Ruminating_Gulp_Breath_Burp"
classifier_type = "svm_rbf"
test_audio_file = os.path.join('E:/Files', 'Acoustic_Data', 'Test', '2min_new.wav')
segments_file = os.path.join('E:/Files', 'Acoustic_Data', 'Test', '2min_new.segments')

SS.train_model_and_classify(training_dirs, model_name, classifier_type, test_audio_file, segments_file,1,0.5,0.1,0.05)
# Out:
# e:\Python\Lib\site-packages\pydub\utils.py:170: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)
# Analyzing file 1 of 30: E:/Files\Acoustic_Data\Ruminating\Ruminating_1.wav
# Analyzing file 2 of 30: E:/Files\Acoustic_Data\Ruminating\Ruminating_10.wav
# Analyzing file 3 of 30: E:/Files\Acoustic_Data\Ruminating\Ruminating_11.wav
# Analyzing file 4 of 30: E:/Files\Acoustic_Data\Ruminating\Ruminating_12.wav
# Analyzing file 5 of 30: E:/Files\Acoustic_Data\Ruminating\Ruminating_13.wav
# Analyzing file 6 of 30: E:/Files\Acoustic_Data\Ruminating\Ruminating_14.wav
# Analyzing file 7 of 30: E:/Files\Acoustic_Data\Ruminating\Ruminating_15.wav
# Analyzing file 8 of 30: E:/Files\Acoustic_Data\Ruminating\Ruminating_16.wav
# Analyzing file 9 of 30: E:/Files\Acoustic_Data\Ruminating\Ruminating_17.wav
# ...

# %%
SS.train_model_and_classify(training_dirs, model_name, classifier_type, test_audio_file, segments_file,1,1,0.1,0.1)
# Out:
# Analyzing file 1 of 30: E:/Files\Acoustic_Data\Ruminating\Ruminating_1.wav
# Analyzing file 2 of 30: E:/Files\Acoustic_Data\Ruminating\Ruminating_10.wav
# Analyzing file 3 of 30: E:/Files\Acoustic_Data\Ruminating\Ruminating_11.wav
# Analyzing file 4 of 30: E:/Files\Acoustic_Data\Ruminating\Ruminating_12.wav
# Analyzing file 5 of 30: E:/Files\Acoustic_Data\Ruminating\Ruminating_13.wav
# Analyzing file 6 of 30: E:/Files\Acoustic_Data\Ruminating\Ruminating_14.wav
# Analyzing file 7 of 30: E:/Files\Acoustic_Data\Ruminating\Ruminating_15.wav
# Analyzing file 8 of 30: E:/Files\Acoustic_Data\Ruminating\Ruminating_16.wav
# Analyzing file 9 of 30: E:/Files\Acoustic_Data\Ruminating\Ruminating_17.wav
# Analyzing file 10 of 30: E:/Files\Acoustic_Data\Ruminating\Ruminating_18.wav
# Analyzing file 11 of 30: E:/Files\Acoustic_Data\Ruminating\Ruminating_19.wav
# Analyzing file 12 of 30: E:/Files\Acoustic_Data\Ruminating\Ruminating_2.wav
# ...

# %%
SS.train_model_and_classify(training_dirs, model_name, classifier_type, test_audio_file, segments_file,1,1,0.1,0.05)
# Out:
# Analyzing file 1 of 30: E:/Files\Acoustic_Data\Ruminating\Ruminating_1.wav
# Analyzing file 2 of 30: E:/Files\Acoustic_Data\Ruminating\Ruminating_10.wav
# Analyzing file 3 of 30: E:/Files\Acoustic_Data\Ruminating\Ruminating_11.wav
# Analyzing file 4 of 30: E:/Files\Acoustic_Data\Ruminating\Ruminating_12.wav
# Analyzing file 5 of 30: E:/Files\Acoustic_Data\Ruminating\Ruminating_13.wav
# Analyzing file 6 of 30: E:/Files\Acoustic_Data\Ruminating\Ruminating_14.wav
# Analyzing file 7 of 30: E:/Files\Acoustic_Data\Ruminating\Ruminating_15.wav
# Analyzing file 8 of 30: E:/Files\Acoustic_Data\Ruminating\Ruminating_16.wav
# Analyzing file 9 of 30: E:/Files\Acoustic_Data\Ruminating\Ruminating_17.wav
# Analyzing file 10 of 30: E:/Files\Acoustic_Data\Ruminating\Ruminating_18.wav
# Analyzing file 11 of 30: E:/Files\Acoustic_Data\Ruminating\Ruminating_19.wav
# Analyzing file 12 of 30: E:/Files\Acoustic_Data\Ruminating\Ruminating_2.wav
# ...

# %%
from utils import Unsupervised_Segmentation as US
import os

audio = os.path.join('E:/Files','Acoustic Data', 'Test_unsupervised.wav')
output_folder = os.path.join('E:/Files','Acoustic Data', 'Test_unsupervised_parts')
US.Unsupervised_segmentation(audio, output_folder, 1, 0.5, 0.1, 6)
# Out:
# e:\Python\Lib\site-packages\pyAudioAnalysis\audioBasicIO.py:99: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampling_rate, signal = wavfile.read(input_file) # from scipy.io
# cluster 0: 0 segments 1.0 sec total dur
# e:\Python\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# cluster 1: 0 segments 1.0 sec total dur
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
# ...
