# %%
from utils import Detection_and_Classification as dc
import os

audio_file = os.path.join('E:/Files', 'Acoustic Data','Test','1min.wav')
output_folder = os.path.join('E:/Files', 'Acoustic Data','Test','1min_segmentation')
model_name, model_type = "svm_Ruminating_Gulp_Breath","svm_rbf"
dc.detection_and_classification(audio_file,output_folder,model_name,model_type,0.1,0.05)
# Out:
# e:\Python\Lib\site-packages\pyAudioAnalysis\audioBasicIO.py:99: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampling_rate, signal = wavfile.read(input_file) # from scipy.io
# ...
