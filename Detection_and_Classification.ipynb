# %%
from utils import Detection_and_Classification as dc
import os

audio_file = os.path.join('E:/Files', 'Acoustic_Data','Cow_600','10min.wav')
output_folder = os.path.join('E:/Files', 'Acoustic_Data','Cow_600','10min_segmentation')
model_name, model_type = "svm_Ruminating_Gulp_Breath_Burp","svm_rbf"
dc.detection_and_classification(audio_file,output_folder,model_name,model_type,0.1,0.05)
# Out:
# E:/Files\Acoustic_Data\Cow_600\10min_segmentation\segment_0_from_0.00to1.00.wav:
# P(Ruminating=0.07718117873880698)
# P(Gulp=0.13773983012439522)
# P(Breath=0.2034999296738561)
# P(Burp=0.581579061462942)
#
# E:/Files\Acoustic_Data\Cow_600\10min_segmentation\segment_100_from_149.25to149.45.wav:
# P(Ruminating=0.20953323234437887)
# P(Gulp=0.08965170894970868)
# P(Breath=0.43764482975623775)
# P(Burp=0.26317022894967496)
#
# E:/Files\Acoustic_Data\Cow_600\10min_segmentation\segment_101_from_149.80to150.35.wav:
# P(Ruminating=0.07526545266698305)
# P(Gulp=0.09194401122095916)
# P(Breath=0.5866753507315522)
# P(Burp=0.24611518538050564)
#
# E:/Files\Acoustic_Data\Cow_600\10min_segmentation\segment_102_from_150.50to150.70.wav:
# P(Ruminating=0.11464803355130805)
# P(Gulp=0.10509190735319136)
# P(Breath=0.4282021854303927)
# P(Burp=0.35205787366510777)
#
# E:/Files\Acoustic_Data\Cow_600\10min_segmentation\segment_103_from_151.35to152.85.wav:
# P(Ruminating=0.02352519523754506)
# ...
